# %% [markdown]
# # IBM Data Science Specialization
# # Capstone Project
# *This notebook will be used for the Captstone Project*<br>
# *Authored by Andrew Dahlstrom*
# ***

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
